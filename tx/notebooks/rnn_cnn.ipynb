# %%
import sys
sys.path.append('../src')
from gc_sampler import GetFeatures
import numpy as np
import pandas as pd

# %%
symbol ='TX_G0.TWF'
colo = 'twf'
dates = []
tick_size = 1.
gf = GetFeatures(symbol=symbol, colo=colo, dates=dates, tick_size=tick_size)
gf.readRawData(path = '../data')
# Out:
# Start reading market data...
# Reading data finished!
# Reading data time usage: 4.44867110252 s

# %%
df = gf.getTrainDataSet()
print df.shape
# Out:
# Generating training sets...
#
# ***** Processing data for 20171106 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 6.30469703674 s
# Extracting image features...
# Extracting finished!
# Extracting time: 5.27286505699 s
# (163612, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 7.95537805557 s
# (163612, 6)
# (163612, 6)
#
# ***** Processing data for 20171113 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 5.84087181091 s
# Extracting image features...
# Extracting finished!
# Extracting time: 5.03017783165 s
# (144130, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 6.98148179054 s
# (144130, 6)
# (144130, 6)
#
# ***** Processing data for 20171129 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 4.48783111572 s
# Extracting image features...
# Extracting finished!
# Extracting time: 4.82993102074 s
# (144301, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 7.31722593307 s
# (144301, 6)
# (144301, 6)
#
# ***** Processing data for 20171103 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 6.02263593674 s
# Extracting image features...
# Extracting finished!
# Extracting time: 5.75843000412 s
# (148719, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 7.89871191978 s
# (148719, 6)
# (148719, 6)
#
# ***** Processing data for 20171130 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 6.15165305138 s
# Extracting image features...
# Extracting finished!
# Extracting time: 7.04167604446 s
# (192086, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 9.59858083725 s
# (192086, 6)
# (192086, 6)
#
# ***** Processing data for 20171116 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 4.83475399017 s
# Extracting image features...
# Extracting finished!
# Extracting time: 5.15234994888 s
# (137477, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 6.96762180328 s
# (137477, 6)
# (137477, 6)
#
# ***** Processing data for 20171121 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 7.36819505692 s
# Extracting image features...
# Extracting finished!
# Extracting time: 9.1266579628 s
# (170226, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 9.64758896828 s
# (170226, 6)
# (170226, 6)
#
# ***** Processing data for 20171109 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 6.86154580116 s
# Extracting image features...
# Extracting finished!
# Extracting time: 6.40919709206 s
# (177393, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 9.44445085526 s
# (177393, 6)
# (177393, 6)
#
# ***** Processing data for 20171204 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 8.38173604012 s
# Extracting image features...
# Extracting finished!
# Extracting time: 6.67481684685 s
# (183236, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 10.3181509972 s
# (183236, 6)
# (183236, 6)
#
# ***** Processing data for 20171127 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 5.2315890789 s
# Extracting image features...
# Extracting finished!
# Extracting time: 6.58538293839 s
# (166955, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 9.79651999474 s
# (166955, 6)
# (166955, 6)
#
# ***** Processing data for 20171107 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 9.51744294167 s
# Extracting image features...
# Extracting finished!
# Extracting time: 5.71932387352 s
# (141991, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 8.24262404442 s
# (141991, 6)
# (141991, 6)
#
# ***** Processing data for 20171122 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 8.49502706528 s
# Extracting image features...
# Extracting finished!
# Extracting time: 11.8787488937 s
# (193054, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 11.044508934 s
# (193054, 6)
# (193054, 6)
#
# ***** Processing data for 20171201 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 7.80192708969 s
# Extracting image features...
# Extracting finished!
# Extracting time: 7.9092810154 s
# (233961, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 10.5533020496 s
# (233961, 6)
# (233961, 6)
#
# ***** Processing data for 20171102 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 6.71334218979 s
# Extracting image features...
# Extracting finished!
# Extracting time: 5.89947891235 s
# (144803, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 8.73547291756 s
# (144803, 6)
# (144803, 6)
#
# ***** Processing data for 20171120 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 6.34722900391 s
# Extracting image features...
# Extracting finished!
# Extracting time: 6.11508989334 s
# (148765, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 9.00374817848 s
# (148765, 6)
# (148765, 6)
#
# ***** Processing data for 20171101 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 7.34456300735 s
# Extracting image features...
# Extracting finished!
# Extracting time: 5.93439602852 s
# (153386, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 9.79081702232 s
# (153386, 6)
# (153386, 6)
#
# ***** Processing data for 20171123 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 6.14865589142 s
# Extracting image features...
# Extracting finished!
# Extracting time: 8.89991688728 s
# (134379, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 8.9405310154 s
# (134379, 6)
# (134379, 6)
#
# ***** Processing data for 20171108 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 4.90998697281 s
# Extracting image features...
# Extracting finished!
# Extracting time: 10.4881248474 s
# (124484, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 7.8048491478 s
# (124484, 6)
# (124484, 6)
#
# ***** Processing data for 20171110 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 8.33318591118 s
# Extracting image features...
# Extracting finished!
# Extracting time: 6.4970471859 s
# (153136, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 10.1844348907 s
# (153136, 6)
# (153136, 6)
#
# ***** Processing data for 20171115 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 7.00211596489 s
# Extracting image features...
# Extracting finished!
# Extracting time: 5.90037798882 s
# (132224, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 8.01527905464 s
# (132224, 6)
# (132224, 6)
#
# ***** Processing data for 20171117 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 7.40369296074 s
# Extracting image features...
# Extracting finished!
# Extracting time: 6.33271408081 s
# (156220, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 10.2305109501 s
# (156220, 6)
# (156220, 6)
#
# ***** Processing data for 20171124 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 6.41678500175 s
# Extracting image features...
# Extracting finished!
# Extracting time: 4.70779681206 s
# (103722, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 5.95313715935 s
# (103722, 6)
# (103722, 6)
#
# ***** Processing data for 20171128 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 7.8005168438 s
# Extracting image features...
# Extracting finished!
# Extracting time: 6.74876785278 s
# (166365, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 10.8222029209 s
# (166365, 6)
# (166365, 6)
#
# ***** Processing data for 20171114 *****
# Extracting other people's behaviors...
# Extracting finished!
# Extracting time: 6.53468489647 s
# Extracting image features...
# Extracting finished!
# Extracting time: 6.89160704613 s
# (167291, 6, 10, 4)
# Extracting Rnn features...
# Extracting finished!
# Extracting time: 11.0157179832 s
# (167291, 6)
# (167291, 6)
# (3267048, 6)
# (3267048, 6)
# (3267048, 6, 10, 4)
# (3267048,)
# Job finished!
# Time usage: 620.99268508 s
# (3267048, 4)

# %%
## Keras
from keras.layers import Input, Dropout, Dense, BatchNormalization, Activation, concatenate, GRU, Embedding, Flatten
from keras.layers import Flatten, Conv2D, MaxPooling2D
from keras.models import Model, Sequential
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping#, TensorBoard
from keras import backend as K
from keras import optimizers
from keras.optimizers import SGD
from keras import initializers
from keras.callbacks import LearningRateScheduler
from keras.utils import np_utils
from keras.preprocessing.sequence import pad_sequences
from sklearn.cross_validation import train_test_split
from keras.utils import np_utils

# %%
dtrain, dvalid = train_test_split(df, random_state=17, train_size=0.7)
print dtrain.columns
print dtrain.img.values[0].shape
# Out:
# Index([u'askp', u'behav', u'bidp', u'img'], dtype='object')
# (6, 10, 4)

# %%
# Function to compute class weights
def comp_cls_wts(y, pwr = 0.5):
    '''
    Used to compute class weights
    '''
    dic = {}
    for x in set(y):
        dic[x] = len(y)**pwr/list(y).count(x)**pwr
    return dic
cls_wts = comp_cls_wts(dtrain.behav.values, pwr=0.5)
print cls_wts
# Out:
# {0: 2.9623885112563246, 1: 2.897094042735395, 2: 8.143745622000402, 3: 8.140677186471262, 4: 2.7812450024034754, 5: 2.776525179715494, 6: 3.8168574598622405, 7: 3.768377882600665, 8: 1.7183196399596146}

# %%
def get_inout_data(dataset):
    X = {
        'ask': np.array(dataset.askp.tolist()).astype(np.int32),
        'bid': np.array(dataset.bidp.tolist()).astype(np.int32),
        'img': np.array(dataset.img.tolist()).astype(np.float32),
        'y': np_utils.to_categorical(dataset.behav.values, num_classes=9)
    }
    return X
# %time tr = get_inout_data(dtrain)
# %time cv = get_inout_data(dvalid)
# Out:
# CPU times: user 10.6 s, sys: 7.89 s, total: 18.5 s
# Wall time: 18.5 s
# CPU times: user 4.31 s, sys: 826 ms, total: 5.13 s
# Wall time: 5.14 s

# %%
print tr['ask'].shape, tr['bid'].shape, tr['img'].shape, tr['y'].shape
MAX_PRICE = np.max([np.max(vec) for vec in tr['ask']] + [np.max(vec) for vec in cv['ask']]) + 5
print MAX_PRICE
# Out:
# (2286933, 6) (2286933, 6) (2286933, 6, 10, 4) (2286933, 9)
# 10882

# %%
ask = Input(shape=[tr['ask'][0].shape[0]], name = 'ask')
bid = Input(shape=[tr['bid'][0].shape[0]], name = 'bid')
print tr['ask'][0].shape[0]
img = Input(shape=(6, 10, 4), name = 'img')
# Out:
# 6

# %%
emb_ask = Embedding(MAX_PRICE, 32)(ask)
emb_bid = Embedding(MAX_PRICE, 32)(bid)
rnn_ask = GRU(16)(emb_ask)
rnn_bid = GRU(16)(emb_bid)
fc_ask = Dropout(0.5) (Dense(64) (rnn_ask))
fc_bid = Dropout(0.5) (Dense(64) (rnn_bid))

# %%
cnn_img = Conv2D(32, kernel_size = (3, 3), padding = 'same', activation='relu') (img)
cnn_img = Dropout(0.25)(cnn_img)
cnn_img = Conv2D(64, kernel_size = (3, 3), padding = 'same', activation='relu') (cnn_img)
cnn_img = Dropout(0.25)(cnn_img)
fc_img = Flatten()(cnn_img)
fc_img = Dropout(0.5) (Dense(128) (fc_img))

# %%
main = concatenate([
    fc_ask,
    fc_bid,
    fc_img
])
main = Dropout(0.5) (Dense(128) (main))
main = Dropout(0.5) (Dense(32) (main))
output = Dense(9, activation="softmax") (main)

# %%
model = Model([ask, bid, img], output)
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# img (InputLayer)                 (None, 6, 10, 4)      0
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 6, 10, 32)     1184
# ____________________________________________________________________________________________________
# dropout_14 (Dropout)             (None, 6, 10, 32)     0
# ____________________________________________________________________________________________________
# ask (InputLayer)                 (None, 6)             0
# ____________________________________________________________________________________________________
# bid (InputLayer)                 (None, 6)             0
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 6, 10, 64)     18496
# ____________________________________________________________________________________________________
# embedding_5 (Embedding)          (None, 6, 32)         348224
# ____________________________________________________________________________________________________
# embedding_6 (Embedding)          (None, 6, 32)         348224
# ____________________________________________________________________________________________________
# dropout_15 (Dropout)             (None, 6, 10, 64)     0
# ____________________________________________________________________________________________________
# gru_5 (GRU)                      (None, 16)            2352
# ____________________________________________________________________________________________________
# gru_6 (GRU)                      (None, 16)            2352
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)              (None, 3840)          0
# ____________________________________________________________________________________________________
# dense_12 (Dense)                 (None, 64)            1088
# ____________________________________________________________________________________________________
# dense_13 (Dense)                 (None, 64)            1088
# ____________________________________________________________________________________________________
# dense_14 (Dense)                 (None, 128)           491648
# ____________________________________________________________________________________________________
# dropout_12 (Dropout)             (None, 64)            0
# ____________________________________________________________________________________________________
# dropout_13 (Dropout)             (None, 64)            0
# ____________________________________________________________________________________________________
# dropout_16 (Dropout)             (None, 128)           0
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 256)           0
# ____________________________________________________________________________________________________
# dense_15 (Dense)                 (None, 128)           32896
# ____________________________________________________________________________________________________
# dropout_17 (Dropout)             (None, 128)           0
# ____________________________________________________________________________________________________
# dense_16 (Dense)                 (None, 32)            4128
# ____________________________________________________________________________________________________
# dropout_18 (Dropout)             (None, 32)            0
# ____________________________________________________________________________________________________
# dense_17 (Dense)                 (None, 9)             297
# ====================================================================================================
# Total params: 1,251,977.0
# Trainable params: 1,251,977.0
# Non-trainable params: 0.0
# ____________________________________________________________________________________________________

# %%
N_epoch = 72
learning_rate = 0.04
decay_rate = 1./1.20
optimizer = SGD(learning_rate)
loss = 'categorical_crossentropy'
metrics = ['accuracy']
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
    
### Train the model
print("TRAINING BEGINS!")
    
## Using adaptive decaying learning rate
def scheduler(epoch):
    global learning_rate
    global decay_rate
    if epoch%6 == 0:
        learning_rate *= decay_rate
        print("CURRENT LEARNING RATE = ", learning_rate)
    return learning_rate
change_lr = LearningRateScheduler(scheduler)
# Out:
# TRAINING BEGINS!

# %%
res = model.fit([tr['ask'], tr['bid'], tr['img']], tr['y'], batch_size = 128, epochs = N_epoch, 
                verbose = 1, validation_data = ([cv['ask'], cv['bid'], cv['img']], cv['y']), 
                class_weight = cls_wts, callbacks = [change_lr])
# Out:
# Train on 2286933 samples, validate on 980115 samples
# ('CURRENT LEARNING RATE = ', 0.03333333333333333)
# Epoch 1/72
